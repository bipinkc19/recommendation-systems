# %% [markdown]
# ### Importing dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Reading movies file
movies = pd.read_csv('movies.csv', sep='\t', encoding='latin-1', usecols=['movie_id', 'title', 'genres'])

# %%
display(movies.head())
display(movies.shape)
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy
# (3883, 3)

# %% [markdown]
# ### Visualizing the words of movies to get a context of the data set

# %%
# Import new libraries
# %matplotlib inline
import wordcloud
from wordcloud import WordCloud, STOPWORDS

# Create a wordcloud of the movie titles
movies['title'] = movies['title'].fillna("").astype('str')
title_corpus = ' '.join(movies['title'])
title_wordcloud = WordCloud(stopwords=STOPWORDS, background_color='black', height=2000, width=4000).generate(title_corpus)

# Plot the wordcloud
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ### Converting the attached genre names to arrays

# %%
movies['genres'] = movies['genres'].str.split('|')
# Convert genres to string value
movies['genres'] = movies['genres'].fillna("").astype('str')

# %% [markdown]
# ### Using TfidfVectorizer to convert the array of genres to seperate columns

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(movies['genres'])
tfidf_matrix.shape
# Out:
# (3883, 127)

# %% [markdown]
# ### Finding the cosine similarity between the records and creating an matrix

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
cosine_sim[:4, :4]
# Out:
# array([[1.        , 0.14193614, 0.09010857, 0.1056164 ],
#        [0.14193614, 1.        , 0.        , 0.        ],
#        [0.09010857, 0.        , 1.        , 0.1719888 ],
#        [0.1056164 , 0.        , 0.1719888 , 1.        ]])

# %% [markdown]
# ### Naming the colums and indexes for knowing which movie the realtions belongs to

# %%
result = pd.DataFrame(data = cosine_sim, columns = movies['title'], index = movies['title'])

# %%
result.head(3)
# Out:
# title                    Toy Story (1995)  Jumanji (1995)  \
# title
# Toy Story (1995)                 1.000000        0.141936
# Jumanji (1995)                   0.141936        1.000000
# Grumpier Old Men (1995)          0.090109        0.000000
#
# title                    Grumpier Old Men (1995)  Waiting to Exhale (1995)  \
# title
# Toy Story (1995)                        0.090109                  0.105616
# Jumanji (1995)                          0.000000                  0.000000
# Grumpier Old Men (1995)                 1.000000                  0.171989
#
# title                    Father of the Bride Part II (1995)  Heat (1995)  \
# title
# Toy Story (1995)                                   0.235233          0.0
# Jumanji (1995)                                     0.000000          0.0
# Grumpier Old Men (1995)                            0.383061          0.0
#
# title                    Sabrina (1995)  Tom and Huck (1995)  \
# title
# Toy Story (1995)               0.090109             0.209844
# Jumanji (1995)                 0.000000             0.676388
# Grumpier Old Men (1995)        1.000000             0.000000
#
# title                    Sudden Death (1995)  GoldenEye (1995)  \
# title
# Toy Story (1995)                         0.0          0.000000
# Jumanji (1995)                           0.0          0.126079
# Grumpier Old Men (1995)                  0.0          0.000000
#
# title                            ...            Bamboozled (2000)  \
# title                            ...
# Toy Story (1995)                 ...                     0.235233
# Jumanji (1995)                   ...                     0.000000
# Grumpier Old Men (1995)          ...                     0.383061
#
# title                    Bootmen (2000)  Digimon: The Movie (2000)  \
# title
# Toy Story (1995)               0.105616                   0.590521
# Jumanji (1995)                 0.000000                   0.237492
# Grumpier Old Men (1995)        0.171989                   0.000000
#
# title                    Get Carter (2000)  Get Carter (1971)  \
# title
# Toy Story (1995)                       0.0                0.0
# Jumanji (1995)                         0.0                0.0
# Grumpier Old Men (1995)                0.0                0.0
#
# title                    Meet the Parents (2000)  Requiem for a Dream (2000)  \
# title
# Toy Story (1995)                        0.235233                         0.0
# Jumanji (1995)                          0.000000                         0.0
